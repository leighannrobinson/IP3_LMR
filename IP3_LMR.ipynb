# %%
import pandas as pd

# %% [markdown]
# #### Question 1

# %%
df=pd.read_csv('weather_2012.csv', low_memory=False)
df
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0     2012-01-01 00:00:00      -1.8                -3.9           86
# 1     2012-01-01 01:00:00      -1.8                -3.7           87
# 2     2012-01-01 02:00:00      -1.8                -3.4           89
# 3     2012-01-01 03:00:00      -1.5                -3.2           88
# 4     2012-01-01 04:00:00      -1.5                -3.3           88
# ...                   ...       ...                 ...          ...
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# ...

# %% [markdown]
# #### Question 2

# %%
# Write the code to display the first five rows of the dataset
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
# the last five rows of the dataset
df.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
#a sample of five random rows from the dataset
df.sample(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 6951  2012-10-16 15:00:00       8.4                 0.7           58
# 3850  2012-06-09 10:00:00      21.0                10.1           50
# 8609  2012-12-24 17:00:00      -9.7               -13.7           73
# 1367  2012-02-26 23:00:00      -9.5               -16.2           58
# 8024  2012-11-30 08:00:00     -12.8               -16.7           73
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# 6951               32             24.1           100.39  Mostly Cloudy
# 3850                4             48.3           100.78   Mainly Clear
# 8609                6             25.0           101.49   Mainly Clear
# 1367                0             25.0           102.64         Cloudy
# 8024               13             48.3           103.12   Mainly Clear

# %% [markdown]
# #### Question 3

# %%
# Write the code to display a list of all of the columns in the dataset
df.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %% [markdown]
# #### Question 4

# %%
# Rename column names
df=df.rename(columns={'Date/Time': 'date_time', 'Temp (C)': 'temp_c',
                     'Dew Point Temp (C)': 'dew_point', 'Rel Hum (%)': 'relative_humidity',
                     'Wind Spd (km/h)': 'wind_speed', 'Visibility (km)': 'visibility',
                    'Stn Press (kPa)': 'pressure', 'Weather': 'weather'})

# %%
df
# Out:
#                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather
# ...

# %% [markdown]
# #### Question 5

# %%
# write the code to get some standard statistics for each column 
df.describe()
# Out:
#             temp_c    dew_point  relative_humidity   wind_speed   visibility  \
# count  8784.000000  8784.000000        8784.000000  8784.000000  8784.000000
# mean      8.798144     2.555294          67.431694    14.945469    27.664447
# std      11.687883    10.883072          16.918881     8.688696    12.622688
# min     -23.300000   -28.500000          18.000000     0.000000     0.200000
# 25%       0.100000    -5.900000          56.000000     9.000000    24.100000
# 50%       9.300000     3.300000          68.000000    13.000000    25.000000
# 75%      18.800000    11.800000          81.000000    20.000000    25.000000
# max      33.000000    24.400000         100.000000    83.000000    48.300000
#
#           pressure
# count  8784.000000
# mean    101.051623
# std       0.844005
# min      97.520000
# 25%     100.560000
# 50%     101.070000
# 75%     101.590000
# max     103.650000

# %% [markdown]
# #### Question 6

# %%
# add a column named temp_f to the dataset that contains the temperature from temp_c represented in Fahrenheit. 
df['temp_f']=(((df['temp_c']*9)/5)+32)
df
# Out:
#                 date_time  temp_c  dew_point  relative_humidity  wind_speed  \
# 0     2012-01-01 00:00:00    -1.8       -3.9                 86           4
# 1     2012-01-01 01:00:00    -1.8       -3.7                 87           4
# 2     2012-01-01 02:00:00    -1.8       -3.4                 89           7
# 3     2012-01-01 03:00:00    -1.5       -3.2                 88           6
# 4     2012-01-01 04:00:00    -1.5       -3.3                 88           7
# ...                   ...     ...        ...                ...         ...
# 8779  2012-12-31 19:00:00     0.1       -2.7                 81          30
# 8780  2012-12-31 20:00:00     0.2       -2.4                 83          24
# 8781  2012-12-31 21:00:00    -0.5       -1.5                 93          28
# 8782  2012-12-31 22:00:00    -0.2       -1.8                 89          28
# 8783  2012-12-31 23:00:00     0.0       -2.1                 86          30
#
#       visibility  pressure               weather  temp_f
# ...

# %% [markdown]
# #### Question 7

# %%
# Write the code to rearrange the columns in the dataset so temp_f appears immediately before temp_c
df = df.reindex(['date_time','temp_f','temp_c','dew_point', 'relative_humidity', 'wind_speed', 
                 'visibility', 'pressure', 'weather'], axis=1)
(df)
# Out:
#                 date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0     2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1     2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2     2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3     2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4     2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
# ...                   ...     ...     ...        ...                ...
# 8779  2012-12-31 19:00:00   32.18     0.1       -2.7                 81
# 8780  2012-12-31 20:00:00   32.36     0.2       -2.4                 83
# 8781  2012-12-31 21:00:00   31.10    -0.5       -1.5                 93
# 8782  2012-12-31 22:00:00   31.64    -0.2       -1.8                 89
# 8783  2012-12-31 23:00:00   32.00     0.0       -2.1                 86
#
#       wind_speed  visibility  pressure               weather
# ...

# %% [markdown]
# #### Question 8

# %%
# display the data types of all the columns in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          8784 non-null   object
#  1   temp_f             8784 non-null   float64
#  2   temp_c             8784 non-null   float64
#  3   dew_point          8784 non-null   float64
#  4   relative_humidity  8784 non-null   int64
#  5   wind_speed         8784 non-null   int64
#  6   visibility         8784 non-null   float64
#  7   pressure           8784 non-null   float64
#  8   weather            8784 non-null   object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 617.8+ KB

# %% [markdown]
# #### Question 9

# %%
# Write the code to convert date_time to a date/time column
df['date_time']=pd.to_datetime(df['date_time'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          8784 non-null   datetime64[ns]
#  1   temp_f             8784 non-null   float64
#  2   temp_c             8784 non-null   float64
#  3   dew_point          8784 non-null   float64
#  4   relative_humidity  8784 non-null   int64
#  5   wind_speed         8784 non-null   int64
#  6   visibility         8784 non-null   float64
#  7   pressure           8784 non-null   float64
#  8   weather            8784 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(1)
# memory usage: 617.8+ KB

# %% [markdown]
# #### Question 10

# %%
# Write the code to get a count of the different weather designations in the weather column
## display top 10 weather categories
df['weather'].value_counts().head(10)
# Out:
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Rain              306
# Rain Showers      188
# Fog               150
# Rain,Fog          116
# Drizzle,Fog        80
# Name: weather, dtype: int64

# %%
weather_topten=df['weather'].value_counts().head(10)
weather_topten.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Question 11

# %%
#Which month of the year, the temp_f more than 90, humidity less than 50 , dew point more than 17, and the weather is clear?
df.query('temp_f>90&relative_humidity<50&dew_point>17&weather=="Clear"')
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 5199 2012-08-04 15:00:00   91.04    32.8       18.8                 44
# 5200 2012-08-04 16:00:00   90.50    32.5       18.5                 44
# 5201 2012-08-04 17:00:00   90.50    32.5       19.8                 47
#
#       wind_speed  visibility  pressure weather
# 5199          17        24.1    101.39   Clear
# 5200          15        24.1    101.34   Clear
# 5201          13        24.1    101.32   Clear

# %% [markdown]
# ##### The month is April

# %%
# Extract that data and save it to a new data frame.
df1=df.query('temp_f>90&relative_humidity<50&dew_point>17&weather=="Clear"')
df1
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 5199 2012-08-04 15:00:00   91.04    32.8       18.8                 44
# 5200 2012-08-04 16:00:00   90.50    32.5       18.5                 44
# 5201 2012-08-04 17:00:00   90.50    32.5       19.8                 47
#
#       wind_speed  visibility  pressure weather
# 5199          17        24.1    101.39   Clear
# 5200          15        24.1    101.34   Clear
# 5201          13        24.1    101.32   Clear

# %% [markdown]
# #### Question 12

# %%
#Extract the month information from the date_time column and add a month column at the data frame
df['month']=df['date_time'].dt.month

# %%
df
# Out:
#                date_time  temp_f  temp_c  dew_point  relative_humidity  \
# 0    2012-01-01 00:00:00   28.76    -1.8       -3.9                 86
# 1    2012-01-01 01:00:00   28.76    -1.8       -3.7                 87
# 2    2012-01-01 02:00:00   28.76    -1.8       -3.4                 89
# 3    2012-01-01 03:00:00   29.30    -1.5       -3.2                 88
# 4    2012-01-01 04:00:00   29.30    -1.5       -3.3                 88
# ...                  ...     ...     ...        ...                ...
# 8779 2012-12-31 19:00:00   32.18     0.1       -2.7                 81
# 8780 2012-12-31 20:00:00   32.36     0.2       -2.4                 83
# 8781 2012-12-31 21:00:00   31.10    -0.5       -1.5                 93
# 8782 2012-12-31 22:00:00   31.64    -0.2       -1.8                 89
# 8783 2012-12-31 23:00:00   32.00     0.0       -2.1                 86
#
#       wind_speed  visibility  pressure               weather  month
# ...

# %% [markdown]
# #### Question 13

# %%
# Save your original dataframe to (‘weather_2012_new.csv’) – ensure your file does not contain the index column of the dataset
df.to_csv('weather_2012_new.csv', index=False)
